# %%
import os
import os.path
import sys
import pandas as pd
from pathlib import Path
sys.path.insert(0, '..')
from elitetools import eddb
eddb.load_feeds()

# %%
origin = 'CD-33 8748'  # input("Origin: ")
origin

# %%
destination = ''  # input("Destination: ")
destination

# %%
waypoints = 'Laksak, Leesti, Deciat, Kuk, Wyrd, Sirius, Alioth'  # input("Waypoints: ")
waypoints

# %%
eddb.route_to_dataframe(eddb.best_route([x.strip() for x in waypoints.split(',')], origin, destination))

# %%
import os
import os.path
import sys
from pathlib import Path
sys.path.insert(0, '..')
from elitetools import eddb
eddb.load_feeds()
# Out:
# # Found "C:\Users\komin\AppData\Local\Temp\elite-tools\archive-v6-commodities.json".
# # Feeds.COMMODITIES records loaded:  373
# # Found "C:\Users\komin\AppData\Local\Temp\elite-tools\archive-v6-listings.csv".
# # Feeds.PRICES records loaded:  4189932
# # Found "C:\Users\komin\AppData\Local\Temp\elite-tools\archive-v6-factions.jsonl".
# # Feeds.FACTIONS records loaded:  77156
# # Found "C:\Users\komin\AppData\Local\Temp\elite-tools\archive-v6-systems_populated.jsonl".
# # Feeds.POPULATED_SYSTEMS records loaded:  20568
# # Found "C:\Users\komin\AppData\Local\Temp\elite-tools\archive-v6-stations.jsonl".
# # Feeds.STATIONS records loaded:  76251
# # Scraping "C:\Users\komin\AppData\Local\Temp\elite-tools\scraped_listings.jsonl".
# # Alexandrite: 25 listings scraped.
# # Benitoite: 25 listings scraped.
# # Bromellite: 25 listings scraped.
# # Grandidierite: 25 listings scraped.
# # Low Temperature Diamonds: 25 listings scraped.
# # Monazite: 25 listings scraped.
# ...

# %% [markdown]
# ## Best Low Temperature Diamond Listings ##

# %%
eddb.best_rt_listings("Mosche", (259-0), top_count=10, by_commodity=['Low Temperature Diamonds'], min_demand=400)
# Out:
#                   Commodity  Sell Price  Demand     As Of  Distance  \
# 0  Low Temperature Diamonds     1159440    5560   10 mins     166.4
# 1  Low Temperature Diamonds     1144280   25920   4 hours      92.8
# 2  Low Temperature Diamonds     1144280   25920   14 mins      92.8
# 3  Low Temperature Diamonds     1144280   25920   45 mins      92.8
# 4  Low Temperature Diamonds     1140130    2442    5 mins     251.3
# 5  Low Temperature Diamonds     1032491    2484   3 hours     137.4
# 6  Low Temperature Diamonds     1032491     907   6 hours     137.4
# 7  Low Temperature Diamonds     1001697    1476  15 hours     125.3
# 8  Low Temperature Diamonds     1001697    2135  13 hours     125.3
# 9  Low Temperature Diamonds      961988    2598   6 hours     148.9
#
#                System           Station Pad
# 0  IV Comae Berenices        Litke Dock   L
# 1            LHS 1020  Babakin Terminal   L
# 2            LHS 1020    Ziewe Terminal   L
# ...

# %% [markdown]
# ## Best Painite Listings ##

# %%
eddb.best_rt_listings("Exioce", 210, top_count=10, by_commodity=['Painite'], min_demand = 200)
# Out:
#   Commodity  Sell Price  Demand    As Of  Distance       System  \
# 0   Painite      792088    1276  21 mins     177.8    HIP 14211
# 1   Painite      792088    1546   5 mins     180.1  Obassi Osaw
# 2   Painite      792088     890  5 hours     109.3        Moram
# 3   Painite      656538    3146  3 hours     160.9    LP 493-64
# 4   Painite      656538    1150  6 hours     160.9    LP 493-64
# 5   Painite      646899     403  6 hours     109.3        Moram
#
#            Station Pad
# 0    Williams Dock   L
# 1  Teller Horizons   L
# 2     Tapinas Ring   L
# 3    Ramanujan Hub   L
# 4   Fossey Gateway   M
# 5  Ziemianski Dock   M

# %% [markdown]
# ## Best Void Opal Listings ##

# %%
eddb.best_rt_listings("Vindinepu", (259-38), top_count=10, by_commodity=['Void Opals'], min_demand=400)
# Out:
#     Commodity  Sell Price  Demand    As Of  Distance              System  \
# 0  Void Opals     1385516    4716  11 mins     142.9  IV Comae Berenices
# 1  Void Opals     1366748    5184  14 mins     108.9            LHS 1020
# 2  Void Opals     1366748    5184  45 mins     108.9            LHS 1020
# 3  Void Opals     1366748    5184  4 hours     108.9            LHS 1020
# 4  Void Opals     1365184    1090  9 hours     135.2              Goller
# 5  Void Opals     1365184     902   1 days     135.2              Goller
# 6  Void Opals     1365184     712  6 hours      65.7               Kamuy
#
#             Station Pad
# 0        Litke Dock   L
# 1    Ziewe Terminal   L
# 2     Arfstrom City   L
# 3  Babakin Terminal   L
# 4    Ban Enterprise   L
# 5         Shaw Port   M
# 6   Ockels Terminal   L

# %% [markdown]
# ## Best Core-Only Mineral Listings in Known Space ##

# %%
eddb.best_rt_listings('Azrael', 0, top_count=5, by_commodity=eddb.core_only_minerals)
# Out:
#         Commodity  Sell Price  Demand    As Of  Distance              System  \
# 0      Void Opals     1385516    4716  11 mins     206.3  IV Comae Berenices
# 1      Void Opals     1385516    4716  11 mins     206.3  IV Comae Berenices
# 2      Void Opals     1385516    4716  11 mins     206.3  IV Comae Berenices
# 3      Void Opals     1385516    4716  11 mins     206.3  IV Comae Berenices
# 4      Void Opals     1385516    4716  11 mins     206.3  IV Comae Berenices
# 5       Benitoite     1191593    1070  2 hours     397.9               Atlas
# 6       Benitoite     1191593    1070  2 hours     397.9               Atlas
# 7       Benitoite     1191593    1070  2 hours     397.9               Atlas
# 8       Benitoite     1191593    1070  2 hours     397.9               Atlas
# 9       Benitoite     1191593    1070  2 hours     397.9               Atlas
# 10    Serendibite      954200    1070  2 hours     397.9               Atlas
# ...

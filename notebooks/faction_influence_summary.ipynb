# %%
import os
import os.path
import sys
from pathlib import Path
sys.path.insert(0, os.path.join(Path.home(), 'Projects', 'elite-tools', 'src'))
import eddb
# Out:
# Using existing file "C:\Users\komin\AppData\Local\Temp\elite-tools\archive-v6-systems_populated.jsonl" for Feeds.POPULATED_SYSTEMS.
# # Feeds.POPULATED_SYSTEMS records loaded:  20629
# Using existing file "C:\Users\komin\AppData\Local\Temp\elite-tools\archive-v6-factions.jsonl" for Feeds.FACTIONS.
# # Feeds.FACTIONS records loaded:  77091

# %%
origin = "Azrael"  # eddb.average_position(input("Systems: "))

# %%
faction = "The Order of Mobius"

# %%
faction_systems = eddb.query_systems_by_faction(faction)
system_summaries = eddb.summarize_faction_systems(faction_systems, origin)
system_summaries.sort_values(by=['Distance'])
# Out:
#                 Name  Distance  Controlling Faction               States  \
# 2             Azrael       0.0  The Order of Mobius  Boom, Civil Liberty
# 0           Apathaam       6.0  The Order of Mobius                 Boom
# 9             Exioce       8.4  The Order of Mobius  Boom, Civil Liberty
# 6             Cardea       9.9  The Order of Mobius                 Boom
# 20             Njiri      12.0  The Order of Mobius                 Boom
# 7             Dvorsi      14.5  The Order of Mobius                 Boom
# 16         Ling Deti      17.3  The Order of Mobius                 None
# 4        Bactondinks      19.5  The Order of Mobius  Boom, Civil Liberty
# 12            Jimavi      19.8  The Order of Mobius                 None
# 18            Maausk      21.0  The Order of Mobius  Boom, Civil Liberty
# 19           Negrito      23.8  The Order of Mobius                 None
# 10       Gongalungul      24.0  The Order of Mobius                 Boom
# ...

# %%
# system_summaries.to_clipboard(header=None, index=False)
